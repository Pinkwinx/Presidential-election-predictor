# %%
import pandas as pd
import pyreadstat

# %%
#reads the .sav file and convert it to a .csv file
og = pd.read_spss('Data/ATP W116.sav')
og.to_csv("Data/Election data.csv", index=False)

# %%
df = pd.read_csv("Data/Election data.csv")
# Out:
# /var/folders/wp/79200sx97gq3ybg9qqyv3h140000gn/T/ipykernel_49174/3749811222.py:1: DtypeWarning: Columns (60) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Data/Election data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5098 entries, 0 to 5097
# Columns: 155 entries, QKEY to WEIGHT_W116
# dtypes: float64(2), object(153)
# memory usage: 6.0+ MB

# %%
df.head()
# Out:
#        QKEY INTERVIEW_START_W116   INTERVIEW_END_W116 DEVICE_TYPE_W116  \
# 0  100363.0  2022-10-11 19:14:45  2022-10-11 19:24:29       Smartphone
# 1  100637.0  2022-10-12 10:36:37  2022-10-12 10:47:37        Laptop/PC
# 2  101437.0  2022-10-11 23:05:48  2022-10-11 23:24:47        Laptop/PC
# 3  101493.0  2022-10-11 16:08:14  2022-10-12 02:11:40       Smartphone
# 4  102198.0  2022-10-12 20:41:45  2022-10-12 20:56:58        Laptop/PC
#
#   LANG_W116 FORM_W116 XCITIZEN_W116 XW78NONRESP_W116        XW91NONRESP_W116  \
# 0   English    Form 2           Yes   Respond to W78          Respond to W91
# 1   English    Form 1           Yes   Respond to W78          Respond to W91
# 2   English    Form 2           Yes   Respond to W78          Respond to W91
# 3   English    Form 1           Yes   Respond to W78          Respond to W91
# 4   English    Form 2           Yes   Respond to W78  Did not respond to W91
#
#      SATIS_W116  ... F_PARTYSUM_FINAL            F_PARTYSUMIDEO_FINAL  \
# ...

# %%
#This will drop all the blank columns and make a new dataset that is
df.dropna(inplace=True)
df.to_csv("Data/ Election data v2.csv", index=False)
